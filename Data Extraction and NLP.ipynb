# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

# %%
url = 'https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/'

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
response = requests.get(url,headers=headers).text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <title>
#    AI and ML-Based YouTube Analytics and Content Creation Tool for Optimizing Subscriber Engagement and Content Strategy | Blackcoffer Insights
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://insights.blackcoffer.com/xmlrpc.php" rel="pingback"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <style>
#    img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }
#   </style>
#   <link href="https://insights.blackcoffer.com/feed/" rel="alternate" title="Blackcoffer Insights » Feed" type="application/rss+xml"/>
# ...

# %%
soup.find_all('h1')[0].text
# Out:
# 'AI and ML-Based YouTube Analytics and Content Creation Tool for Optimizing Subscriber Engagement and Content Strategy'

# %%
soup.find('h1', class_='entry-title')
# Out:
# <h1 class="entry-title">AI and ML-Based YouTube Analytics and Content Creation Tool for Optimizing Subscriber Engagement and Content Strategy</h1>

# %%
soup.find('h1', class_='entry-title').text
# Out:
# 'AI and ML-Based YouTube Analytics and Content Creation Tool for Optimizing Subscriber Engagement and Content Strategy'

# %%
soup.find_all('strong')
# Out:
# [<strong>Client Background</strong>,
#  <strong>Client:</strong>,
#  <strong>Industry Type: </strong>,
#  <strong>Products &amp; Services: </strong>,
#  <strong>Organization Size:</strong>,
#  <strong>The Problem</strong>,
#  <strong>Our Solution</strong>,
#  <strong>Solution Architecture</strong>,
#  <strong>Deliverables</strong>,
#  <strong>Tech Stack</strong>,
#  <strong>Tools used</strong>,
#  <strong>Language/techniques used</strong>,
#  <strong>Models used</strong>,
#  <strong>Skills used</strong>,
#  <strong>Databases used</strong>,
#  <strong>Web Cloud Servers used</strong>,
#  <strong>Project Snapshots </strong>,
#  <strong>Project website url</strong>,
#  <strong>Summarize</strong>,
#  <strong>Contact Details</strong>]

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

final_output = ""

try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()

    soup = BeautifulSoup(response.content, 'html.parser')

    title_element = soup.find('h1', class_='entry-title')
    title_text = title_element.get_text(strip=True) if title_element else "Title Not Found"

    article_body_element = soup.find('div', class_='td-post-content')

    if article_body_element:
        article_text = article_body_element.get_text(separator='\n', strip=True)
    else:
        article_text = "Article content not found."

    final_output = f"{title_text}\n\n{article_text}"

except requests.exceptions.RequestException as e:
    final_output = f"An error occurred while fetching the URL: {e}"
except Exception as e:
    final_output = f"An error occurred during parsing: {e}"

print(final_output)
# Out:
# AI and ML-Based YouTube Analytics and Content Creation Tool for Optimizing Subscriber Engagement and Content Strategy
#
# Client Background
# Client:
# A leading IT & tech firm in the USA
# Industry Type:
# IT
# Products & Services:
# IT Consulting, IT Support, SaaS, Marketing Strategy
# Organization Size:
# 10+
# The Problem
# Building AI and ML based YouTube analytics and content creation tool that will help youtuber to understand their subscriber’s watching behaviour, help them in content research, creation and publication.
# Our Solution
# Created a MERN stack web application and integrated AI models to helps youtuber to generated titles, descriptions, tags, hashtags, captions etc. Help them to check thumbnail quality, analysis on the videos using video auditor tool, analysis on comments using sentiments analysis, help to under their subscribers using churn predication AI model.
# Solution Architecture
# ...

# %%
type(final_output)
# Out:
# str

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Use the exact file path you provided
# The 'r' before the string is important for Windows paths
file_path = r"C:\Users\Admin\Desktop\BLACKCOFFER\Input.xlsx"
final_output = ""

try:
    # 1. Read the Excel file (using read_excel for .xlsx files)
    df = pd.read_excel(file_path)
    
    # 2. Get the URL from the first row of the 'URL' column
    url = df.iloc[0]['URL']
    
    print(f"Successfully read URL from file: {url}")
    
    # 3. Proceed with the scraping logic
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    response = requests.get(url, headers=headers)
    response.raise_for_status() # Check for request errors

    soup = BeautifulSoup(response.content, 'html.parser')

    # Find and extract the title safely
    title_element = soup.find('h1', class_='entry-title')
    title_text = title_element.get_text(strip=True) if title_element else "Title Not Found"

    # Find and extract the article body safely
    article_body_element = soup.find('div', class_='td-post-content')
    if article_body_element:
        article_text = article_body_element.get_text(separator='\n', strip=True)
    else:
        article_text = "Article content not found."

    final_output = f"{title_text}\n\n{article_text}"

except FileNotFoundError:
    final_output = f"Error: The file was not found at the path: {file_path}"
except Exception as e:
    final_output = f"An error occurred: {e}"
print(final_output)
# Out:
# Successfully read URL from file: https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# AI and ML-Based YouTube Analytics and Content Creation Tool for Optimizing Subscriber Engagement and Content Strategy
#
# Client Background
# Client:
# A leading IT & tech firm in the USA
# Industry Type:
# IT
# Products & Services:
# IT Consulting, IT Support, SaaS, Marketing Strategy
# Organization Size:
# 10+
# The Problem
# Building AI and ML based YouTube analytics and content creation tool that will help youtuber to understand their subscriber’s watching behaviour, help them in content research, creation and publication.
# Our Solution
# ...

# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup

def extract_and_save_article(url, url_id, save_directory):
    """
    Extracts the title and text from a URL and saves it to a text file.
    
    Args:
        url (str): The URL of the article to scrape.
        url_id (str): The unique ID for the URL, used for the filename.
        save_directory (str): The folder where the text file will be saved.
    """
    try:
        # Define headers to mimic a real browser visit
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        
        # Fetch the webpage content
        response = requests.get(url, headers=headers)
        response.raise_for_status() # Raise an error for bad responses (e.g., 404)

        # Parse the HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the article title using its specific class
        title_element = soup.find('h1', class_='entry-title')
        title_text = title_element.get_text(strip=True) if title_element else "Title Not Found"

        # Find the article's main content container
        article_body_element = soup.find('div', class_='td-post-content')

        # Safely extract the text, providing a default if not found
        if article_body_element:
            article_text = article_body_element.get_text(separator='\n', strip=True)
        else:
            article_text = "Article content not found."

        # Combine title and article text as per the objective
        final_text_to_save = f"{title_text}\n\n{article_text}"

        # Create the full file path and save the content
        file_path = os.path.join(save_directory, f"{url_id}.txt")
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(final_text_to_save)
        
        # Return True for success
        return True

    except requests.exceptions.RequestException:
        # If there's a network error, we'll note it
        return False
    except Exception:
        # For any other errors during scraping
        return False

# --- Main Execution Block ---

# 1. Define file paths and settings
input_file_path = r"C:\Users\Admin\Desktop\BLACKCOFFER\Input.xlsx"
output_folder = "extracted_articles"

# 2. Create the output folder if it doesn't already exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Created directory: {output_folder}")

# 3. Read the input Excel file
print(f"Reading URLs from {input_file_path}...")
try:
    df = pd.read_excel(input_file_path)
    
    successful_extractions = 0
    failed_extractions = 0

    # 4. Loop through each row of the DataFrame
    for index, row in df.iterrows():
        url_id = row['URL_ID']
        url = row['URL']
        
        print(f"Processing {url_id}: {url}")
        
        success = extract_and_save_article(url, url_id, output_folder)
        
        if success:
            successful_extractions += 1
        else:
            failed_extractions += 1
            print(f"-> Failed to extract article for URL_ID: {url_id}")

    print("\n--- Data Extraction Complete ---")
    print(f"Successfully saved: {successful_extractions} articles")
    print(f"Failed to extract: {failed_extractions} articles")

except FileNotFoundError:
    print(f"Error: The input file was not found at the specified path: {input_file_path}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Created directory: extracted_articles
# Reading URLs from C:\Users\Admin\Desktop\BLACKCOFFER\Input.xlsx...
# Processing Netclan20241017: https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/
# Processing Netclan20241018: https://insights.blackcoffer.com/enhancing-front-end-features-and-functionality-for-improved-user-experience-and-dashboard-accuracy-in-partner-hospital-application/
# Processing Netclan20241019: https://insights.blackcoffer.com/roas-dashboard-for-campaign-wise-google-ads-budget-tracking-using-google-ads-ap/
# Processing Netclan20241020: https://insights.blackcoffer.com/efficient-processing-and-analysis-of-financial-data-from-pdf-files-addressing-formatting-inconsistencies-and-ensuring-data-integrity-for-a-toyota-dealership-management-firm/
# Processing Netclan20241021: https://insights.blackcoffer.com/development-of-ea-robot-for-automated-trading/
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

def extract_article_data(url: str) -> tuple[str, str]:
    """
    Extracts the title and clean text from a given URL.

    Args:
        url (str): The URL of the article to scrape.

    Returns:
        tuple: A tuple containing the extracted (title, article_text).
               Returns error messages in the tuple if extraction fails.
    """
    try:
        # Set headers to mimic a real browser visit
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        # Use a timeout to prevent the script from hanging on a single URL
        response = requests.get(url, headers=headers, timeout=15)
        response.raise_for_status()  # This will raise an HTTPError for bad responses (4xx or 5xx)

        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the article title using its specific class
        title_element = soup.find('h1', class_='entry-title')
        title_text = title_element.get_text(strip=True) if title_element else "Title Not Found"

        # Find the article's main content container
        article_body_element = soup.find('div', class_='td-post-content')

        # Safely extract the text
        if article_body_element:
            article_text = article_body_element.get_text(separator='\n', strip=True)
        else:
            article_text = "Article content not found."
            
        return title_text, article_text

    except requests.exceptions.RequestException as e:
        # Handle network-related errors (e.g., timeout, connection error)
        return "Extraction Failed", f"Request Error: {e}"
    except Exception as e:
        # Handle any other unexpected errors during parsing
        return "Extraction Failed", f"Parsing Error: {e}"

# --- Main Execution Block ---

# 1. Define the input and output file names
# Assumes the input file is in the same directory as the script
input_file = r"C:\Users\Admin\Desktop\BLACKCOFFER\Input.xlsx"
output_file = 'extracted_articles.csv'

# 2. Read the input file
try:
    print(f"Reading URLs from '{input_file}'...")
    df = pd.read_excel(input_file)

    # 3. Create lists to store the results
    titles = []
    articles = []
    
    # 4. Initialize the progress bar and loop through the URLs
    # tqdm provides a helpful visual progress bar for long-running loops
    for url in tqdm(df['URL'], desc="Extracting Articles"):
        title, article = extract_article_data(url)
        titles.append(title)
        articles.append(article)

    # 5. Add the extracted data as new columns to the DataFrame
    df['TITLE'] = titles
    df['ARTICLE_TEXT'] = articles
    
    # 6. Save the updated DataFrame to a new CSV file
    # Set encoding to 'utf-8-sig' to ensure compatibility with Excel
    df.to_csv(output_file, index=False, encoding='utf-8-sig')

    print("\n--- Process Complete ---")
    print(f"Successfully extracted {len(df)} articles.")
    print(f"DataFrame with extracted text has been saved to: '{output_file}'")

except FileNotFoundError:
    print(f"Error: The input file '{input_file}' was not found. Please make sure it's in the same directory.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Reading URLs from 'C:\Users\Admin\Desktop\BLACKCOFFER\Input.xlsx'...
# Extracting Articles: 100%|███████████████████████████████████████████████████████████| 147/147 [24:11<00:00,  9.88s/it]
# --- Process Complete ---
# Successfully extracted 147 articles.
# DataFrame with extracted text has been saved to: 'extracted_articles.csv'
